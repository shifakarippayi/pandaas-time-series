# %% [markdown]
# **Pandas Time Series**

# %% [markdown]
# We can find out the data within a certain range of data and time by using pandas module named time series
#
# Equivalent to date time python package
#
# Used to deal with date time
#
# Compex operation on date time can be done
#
# Timestamp
#
# 21-jan- 2015
#
# 21-01-2024
#
# 21-01-24
#
# 21-01=2024-30:12:11

# %%
data= '15-january-2024'

# %%
type(data)
# Out:
# str

# %%
import pandas as pd
dt= pd.to_datetime(data,format='%d-%B-%Y')
dt
# Out:
# Timestamp('2024-01-15 00:00:00')

# %% [markdown]
# %d 01,22,23
#
# %B january ,march
#
# %b jan, mar
#
# % m int (month in integer)
#
# %y 20,21
#
# Y 2012,2024
#
# %H 24 hr
#
# % I 12hr
#
# % M minute
#
# %S seconds

# %%
type(dt)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
dates=['2021-11-25 2:30:00 PM','jan 5 ,2020 18:45:00','01/11/2020','2020.01.11','2020/-1/11','20201105']
import pandas as pd
date_time = pd.to_datetime(dates)
date_time
# Out:
# <ipython-input-5-060e9773ea46>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   date_time = pd.to_datetime(dates)
# DatetimeIndex(['2021-11-25 14:30:00', '2020-01-05 18:45:00',
#                '2020-01-11 00:00:00', '2020-01-11 00:00:00',
#                '2020-01-11 00:00:00', '2020-11-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
import pandas as pd
dates= "11-jan-20"
date_time= pd.to_datetime(dates)
print(date_time)
print(date_time.day)
print(date_time.week)
print(date_time.day_of_year)
print(date_time.day_of_year)
print(date_time.is_leap_year)
print(date_time.is_month_end)
print(date_time.is_month_start)
print(date_time.month)
print(date_time.quarter)
# Out:
# 2020-01-11 00:00:00
# 11
# 2
# 11
# 11
# True
# False
# False
# 1
# 1

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/shirpurGoldRefinery (1).csv')
df
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 0    29-December-2017      203.55       206.5     201.00       201.85
# 1    28-December-2017      202.00       207.6     199.55       202.80
# 2    27-December-2017      209.10       213.6     195.20       197.80
# 3    26-December-2017      216.50       219.9     207.20       209.70
# 4    22-December-2017      218.95       233.6     212.40       218.15
# ..                ...         ...         ...        ...          ...
# 243    6-January-2017      110.10       110.1     107.80       110.10
# 244    5-January-2017      101.00       104.9     100.00       104.90
# 245    4-January-2017       99.50       102.0      99.50        99.95
# 246    3-January-2017      102.00       102.0     100.05       100.65
# 247    2-January-2017      104.00       104.0      99.00       101.65
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
df.iat[0,0]
# Out:
# '29-December-2017'

# %%
type(df.iat[0,0])
# Out:
# str

# %%
df['timestamp']=pd.to_datetime(df['Date'])

# %%
df.head(2)
# Out:
#                Date  Open Price  High Price  Low Price  Close Price  \
# 0  29-December-2017      203.55       206.5     201.00       201.85
# 1  28-December-2017      202.00       207.6     199.55       202.80
#
#           WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  202.760380          3372             68              683708.0
# 1  203.118439          8612            196             1749256.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                  2202                      65.30             5.50
# 1                  5063                      58.79             8.05
#
#    Spread Close-Open  timestamp
# 0               -1.7 2017-12-29
# 1                0.8 2017-12-28

# %%
import pandas as pd
import numpy as numpy
df= pd.read_csv('/content/drive/MyDrive/shirpurGoldRefinery (1).csv')
df
# Out:
#                  Date  Open Price  High Price  Low Price  Close Price  \
# 0    29-December-2017      203.55       206.5     201.00       201.85
# 1    28-December-2017      202.00       207.6     199.55       202.80
# 2    27-December-2017      209.10       213.6     195.20       197.80
# 3    26-December-2017      216.50       219.9     207.20       209.70
# 4    22-December-2017      218.95       233.6     212.40       218.15
# ..                ...         ...         ...        ...          ...
# 243    6-January-2017      110.10       110.1     107.80       110.10
# 244    5-January-2017      101.00       104.9     100.00       104.90
# 245    4-January-2017       99.50       102.0      99.50        99.95
# 246    3-January-2017      102.00       102.0     100.05       100.65
# 247    2-January-2017      104.00       104.0      99.00       101.65
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
df['Date']=pd. to_datetime(df['Date'],format='%d-%B-%Y')
df.head(2)
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1 2017-12-28      202.00       207.6     199.55       202.80  203.118439
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          3372             68              683708.0                  2202
# 1          8612            196             1749256.0                  5063
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      65.30             5.50               -1.7
# 1                      58.79             8.05                0.8

# %%
df['day']=pd.DatetimeIndex(df['Date']).day
df['year']=pd.DatetimeIndex(df['Date']).year
df['month']= pd.DatetimeIndex(df['Date']).month
df.head(2)
# Out:
#         Date  Open Price  High Price  Low Price  Close Price         WAP  \
# 0 2017-12-29      203.55       206.5     201.00       201.85  202.760380
# 1 2017-12-28      202.00       207.6     199.55       202.80  203.118439
#
#    No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0          3372             68              683708.0                  2202
# 1          8612            196             1749256.0                  5063
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open  day  year  \
# 0                      65.30             5.50               -1.7   29  2017
# 1                      58.79             8.05                0.8   28  2017
#
#    month
# 0     12
# 1     12
